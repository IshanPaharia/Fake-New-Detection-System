# %% [markdown]
# # Fake News Detector

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Installing Necessary Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import string
import re
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %% [markdown]
# ## Loading the data

# %%
data_fake=pd.read_csv('/content/drive/MyDrive/DscProj/Fake-News-Detection/Fake.csv')
data_true=pd.read_csv('/content/drive/MyDrive/DscProj/Fake-News-Detection/True.csv')

# %% [markdown]
# ### Data Preview

# %%
data_fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
data_true.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date
# 21412  August 22, 2017
# 21413  August 22, 2017
# 21414  August 22, 2017
# 21415  August 22, 2017
# 21416  August 22, 2017

# %%
data_fake["class"]=0
data_true['class']=1

# %%
data_fake.shape, data_true.shape
# Out:
# ((23481, 5), (21417, 5))

# %%
data_fake_manual_testing = data_fake.tail(10)
for i in range(23480,23470,-1):
    data_fake.drop([i],axis = 0, inplace = True)


data_true_manual_testing = data_true.tail(10)
for i in range(21416,21406,-1):
    data_true.drop([i],axis = 0, inplace = True)

# %%
data_fake.shape, data_true.shape
# Out:
# ((23471, 5), (21407, 5))

# %%
data_fake_manual_testing.loc[:, 'class'] = 0
data_true_manual_testing.loc[:, 'class'] = 1

# %%
data_fake_manual_testing.head(10)
# Out:
#                                                    title  \
# 23471  Seven Iranians freed in the prisoner swap have...
# 23472                      #Hashtag Hell & The Fake Left
# 23473  Astroturfing: Journalist Reveals Brainwashing ...
# 23474          The New American Century: An Era of Fraud
# 23475  Hillary Clinton: ‘Israel First’ (and no peace ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 23471  21st Century Wire says This week, the historic...  Middle-east
# 23472   By Dady Chery and Gilbert MercierAll writers ...  Middle-east
# 23473  Vic Bishop Waking TimesOur reality is carefull...  Middle-east
# ...

# %%
data_true_manual_testing.head(10)
# Out:
#                                                    title  \
# 21407  Mata Pires, owner of embattled Brazil builder ...
# 21408  U.S., North Korea clash at U.N. forum over nuc...
# 21409  U.S., North Korea clash at U.N. arms forum on ...
# 21410  Headless torso could belong to submarine journ...
# 21411  North Korea shipments to Syria chemical arms a...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21407  SAO PAULO (Reuters) - Cesar Mata Pires, the ow...  worldnews
# 21408  GENEVA (Reuters) - North Korea and the United ...  worldnews
# 21409  GENEVA (Reuters) - North Korea and the United ...  worldnews
# ...

# %%
data_merge=pd.concat([data_fake, data_true], axis = 0)
data_merge.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# ...

# %% [markdown]
# #### "title", "subject" and "date" columns is not required for detecting the fake news, so We will drop them

# %%
data_merge.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'class'], dtype='object')

# %%
data=data_merge.drop(['title','subject','date'], axis = 1)

# %%
#count of missing values
data.isnull().sum()
# Out:
# text     0
# class    0
# dtype: int64

# %% [markdown]
# #### Randomly shuffling the dataframe

# %%
data = data.sample(frac = 1)

# %%
data.head()
# Out:
#                                                     text  class
# 3787   Donald Trump wants to rule America from his go...      0
# 11982  KABUL (Reuters) - One of Afghanistan s most po...      1
# 3537   There s a petition on Change.org going around ...      0
# 7658   WASHINGTON (Reuters) - Donald Trump has given ...      1
# 16654  Here s yet another example of the leadership i...      0

# %%
data.reset_index(inplace = True)
data.drop(['index'], axis = 1, inplace = True)

# %%
data.columns
# Out:
# Index(['text', 'class'], dtype='object')

# %%
data.head()
# Out:
#                                                 text  class
# 0  Donald Trump wants to rule America from his go...      0
# 1  KABUL (Reuters) - One of Afghanistan s most po...      1
# 2  There s a petition on Change.org going around ...      0
# 3  WASHINGTON (Reuters) - Donald Trump has given ...      1
# 4  Here s yet another example of the leadership i...      0

# %% [markdown]
# ## Preprocessing Text

# %% [markdown]
# #### Creating a function to convert the text in lowercase, remove the extra space, special chr., ulr and links.

# %%
def wordopt(text):
    text = text.lower()
    text = re.sub('\[.*?\]','',text)
    text = re.sub("\\W"," ",text)
    text = re.sub('https?://\S+|www\.\S+','',text)
    text = re.sub('<.*?>+',b'',text)
    text = re.sub('[%s]' % re.escape(string.punctuation),'',text)
    text = re.sub('\w*\d\w*','',text)
    return text

# %%
data['text'] = data['text'].apply(wordopt)

# %% [markdown]
# #### Defining dependent and independent variable as x and y

# %%
x = data['text']
y = data['class']

# %% [markdown]
# ## Training the model

# %% [markdown]
# #### Splitting the dataset into training set and testing set.

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size = 0.25)

# %% [markdown]
# ### Extracting Features from the Text

# %% [markdown]
# #### Convert text to vectors

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorization = TfidfVectorizer()
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9845811051693405

# %%
print (classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      5932
#            1       0.98      0.99      0.98      5288
#
#     accuracy                           0.98     11220
#    macro avg       0.98      0.98      0.98     11220
# weighted avg       0.98      0.98      0.98     11220

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

DT = DecisionTreeClassifier()
DT.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = DT.predict(xv_test)

# %%
DT.score(xv_test, y_test)
# Out:
# 0.996078431372549

# %%
print (classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      5932
#            1       0.98      0.99      0.98      5288
#
#     accuracy                           0.98     11220
#    macro avg       0.98      0.98      0.98     11220
# weighted avg       0.98      0.98      0.98     11220

# %% [markdown]
# ## Gradient Boost Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier

GB = GradientBoostingClassifier(random_state = 0)
GB.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
pred_gb = GB.predict(xv_test)

# %%
GB.score(xv_test, y_test)
# Out:
# 0.9948306595365419

# %%
print(classification_report(y_test, pred_gb))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00      5932
#            1       0.99      1.00      0.99      5288
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %% [markdown]
# ## Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

RF = RandomForestClassifier(random_state = 0)
RF.fit(xv_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
pred_rf = RF.predict(xv_test)

# %%
RF.score(xv_test, y_test)
# Out:
# 0.9894830659536542

# %%
print (classification_report(y_test, pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5932
#            1       0.99      0.99      0.99      5288
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %% [markdown]
# ## Testing the Model

# %%
from sklearn.metrics import confusion_matrix, roc_curve, auc
import matplotlib.pyplot as plt
import seaborn as sns

# 1) Collect your trained models into a dict
models = {
    "Logistic Regression": LR,
    "Decition Tree": DT,
    "Random Forest": RF,
    "Gradient Boosting": GB,
}

# 2) Create a big figure with 2 columns per model
n = len(models)
plt.figure(figsize=(10, 5 * n))

for i, (name, model) in enumerate(models.items(), start=1):
    # predictions and probabilities
    y_pred = model.predict(xv_test)
    # some models (e.g. SVM) need decision_function; if no predict_proba, use:
    # y_score = model.decision_function(xv_test)
    y_score = model.predict_proba(xv_test)[:, 1]

    # --- Confusion Matrix subplot ---
    cm = confusion_matrix(y_test, y_pred)
    ax1 = plt.subplot(n, 2, 2*i - 1)
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", ax=ax1)
    ax1.set_title(f"{name} — Confusion Matrix")
    ax1.set_xlabel("Predicted")
    ax1.set_ylabel("Actual")

    # --- ROC Curve subplot ---
    fpr, tpr, _ = roc_curve(y_test, y_score)
    roc_auc = auc(fpr, tpr)
    ax2 = plt.subplot(n, 2, 2*i)
    ax2.plot(fpr, tpr, label=f"AUC = {roc_auc:.2f}")
    ax2.plot([0, 1], [0, 1], "--", label="Chance")
    ax2.set_title(f"{name} — ROC Curve")
    ax2.set_xlabel("False Positive Rate")
    ax2.set_ylabel("True Positive Rate")
    ax2.legend(loc="lower right")

plt.tight_layout()
plt.show()

# %%
import numpy as np

data['word_count']      = data['text'].apply(lambda t: len(t.split()))
data['char_count']      = data['text'].apply(len)
data['avg_word_length'] = data['text'].apply(lambda t: np.mean([len(w) for w in t.split()]) if t.split() else 0)

corr = data[['word_count','char_count','avg_word_length','class']].corr()

plt.figure(figsize=(5,4))
sns.heatmap(corr, annot=True, fmt=".2f", cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# ### Model Testing With Manual Entry

# %%
# I used NGROK to port forward, so I can host on colab itself and access the website too.

import os
os.chdir('/content/drive/MyDrive/DscProj/Fake-News-Detection')
# !python app.py
